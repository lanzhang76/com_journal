# %% [markdown]
# ## Building functions that allow adding and subtracting comedians from the corpus
# 1. provide a dictionary of selections that contain their transcript index number
# 2. asks for user input to select a name from the selections{}
# 3. the comedian and all his transcripts will be added to the context dictionary
# 4. using corpus function to generate a text that will be used to create our Markov Chain model

# %%
context = {

}

# %% [markdown]
# louis: 275-[snoring]

# %%
selections = {
    'bill maher': [0, 4, 8, 13, 15, 17, 91, 94, 102, 104],
    'Sarah Silverman': [84],
    'Aziz Ansari': [23,197,198],
    'Jerry Seinfeld': [47], 
    'Amy Schumer': [49,76],
    'Ali Wong':[132,237],
    'Hasan Minhaj':[217],
    'Louis C.K.':[83,85,270,275,289,290,311]
}

# %%
import pandas as pd
file = pd.read_csv('../jan14/300Full_transcripts.csv')
a = 311
corpus = file.scripts[a]
corpus = corpus.replace('\\','').replace('\', \'',' ').replace('\']','').replace('[\'','').replace('xa0',' ')
print(file.title[a])
print(corpus)
# Out:
# LOUIS C.K.: 2017 – Full transcript
# ...

# %%
name = input("who you want to add?")
if selections.get(name) is not None:
    context[name] = [file.scripts[i] for i in selections.get(name)]
    print(f"{name} is added to the corpus")
else:
    print('select again')
# Out:
# who you want to add?bill maher

# %%
#context.pop('Jerry Seinfeld')

# %%
corpus = ""
for i in context:
    for e in context[i]:
        corpus += e
corpus = corpus.replace('\', \'',' ').replace('\']','').replace('[\'','').replace('xa0',' ')

# %% [markdown]
# ## add a comedian's style from the selection to the current dictionary

# %%
def addToCorpus(csv_file,name):
    file = pd.read_csv(csv_file)
    if selections.get(name) is not None:
        context[name] = [file.scripts[i] for i in selections.get(name)]
        print(f"{name} is added to the corpus")
    else:
        print("your selection is incorrect. Try again")

# %%
addToCorpus('../jan7/300Full_transcripts.csv','Amy Schumer')
# Out:
# Amy Schumer is added to the corpus

# %% [markdown]
# ## build a corpus from a dictionary of names and their transcripts

# %%
def buildCorpus(context):
    corpus = ""
    for i in context:
        for e in context[i]:
            corpus += e
    corpus = corpus.replace('\', \'',' ').replace('\']','').replace('[\'','').replace('xa0',' ').replace('\\','')
    return corpus

# %% [markdown]
# ## delete from the current dictionary

# %%
def delFromCorpus(context_dict,name):
    try:
        context_dict.pop(name)
        print(f"{name} is deleted from the dictionary")
    except:
        print(f"sorry, {name} is not in the dictionary. It cannot be deleted.")
        print(f"{[i for i in context]} are in the dictionary.")

# %%
delFromCorpus(context,'Jerry')
# Out:
# sorry, Jerry is not in the dictionary. It cannot be deleted.
# ['bill maher', 'Amy Schumer'] are in the dictionary.

# %%
print([e for e in [i for i in context]])
# Out:
# ['bill maher', 'Amy Schumer']

# %%
test = file

# %%
test.rename(columns={"Unnamed: 0":'indexx', "title":"title2","script":'script'})
# Out:
#      indexx                                             title2  \
# 0         0  New Rule: Prickstarter | Real Time with Bill M...
# 1         1               Bill Cosby: Playboy Interview (1985)
# 2         2  Sebastian Maniscalco Stand-Up – The Tonight Sh...
# 3         3     Nikki Glaser: Bangin’ (2019) – Full Transcript
# 4         4  New Rule: White Shame | Real Time with Bill Ma...
# ..      ...                                                ...
# 315     113  George Carlin: Complaints and Grievances (2001...
# 316     114           ROBIN WILLIAMS: PLAYBOY INTERVIEW (1992)
# 317     115  GEORGE CARLIN: LIFE IS WORTH LOSING (2006) – F...
# 318     116  George Carlin: It’s Bad For Ya (2008) Full tra...
# 319     117                   George Carlin: Playboy Interview
#
#                                                scripts
# 0    ['New rule: to the woman who got vomit in her ...
# 1    ['Go figure out America’s taste in television....
# ...

# %%
test= test.rename(columns={"Unnamed: 0":'indexx', "title":"title2","script":'script'})

# %%
for t in range(len(test.title2)):
    print(test.indexx[t])
    print(test.title2[t])
# Out:
# 0
# New Rule: Prickstarter | Real Time with Bill Maher (HBO)
# 1
# Bill Cosby: Playboy Interview (1985)
# 2
# Sebastian Maniscalco Stand-Up – The Tonight Show Starring Jimmy Fallon (2019) – Full Transcript
# 3
# Nikki Glaser: Bangin’ (2019) – Full Transcript
# 4
# New Rule: White Shame | Real Time with Bill Maher (HBO) – Transcript
# 5
# Ryan Hamilton Stand-Up – The Tonight Show Starring Jimmy Fallon (2019) – Full Transcript
# 6
# Mark Normand Stand-Up – The Tonight Show Starring Jimmy Fallon (2019) – Full Transcript
# 7
# George Carlin: Dumb Americans (2006) – Full Transcript
# 8
# New Rule: The Fudge Report | Real Time with Bill Maher (HBO)
# 9
# Bill Burr: Paper Tiger (2019) – Full Transcript
# 10
# Dave Chappelle: Sticks and Stones | Epilogue: The Punchline – Full Transcript
# 11
# Brazil, Corruption and the Amazon Rainforest | Patriot Act with Hasan Minhaj – Full Transcript
# 12
# Dave Chappelle: Sticks & Stones (2019) – Full Transcript
# 13
# ...

# %%
test.index()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-94-a33f541c06b1> in <module>
# ----> 1 test.index('0')
#
# TypeError: 'RangeIndex' object is not callable

# %%
def getIndexes(dfObj, value):
    ''' Get index positions of value in dataframe i.e. dfObj.'''
 
    listOfPos = list()
    # Get bool dataframe with True at positions where the given value exists
    result = dfObj.isin([value])
    # Get list of columns that contains the value
    seriesObj = result.any()
    columnNames = list(seriesObj[seriesObj == True].index)
    # Iterate over list of columns and fetch the rows indexes where value exists
    for col in columnNames:
        rows = list(result[col][result[col] == True].index)
        for row in rows:
            listOfPos.append((row, col))
    # Return a list of tuples indicating the positions of value in the dataframe
    return listOfPos

# %%
getIndexes(test,'LOUIS C.K.: 2017 – Full transcript')
# Out:
# [(311, 'title2')]

# %%
print
# Out:
#   File "<ipython-input-102-607852cef684>", line 1
#     print('Fuck, yeah! This is such a big night for you. but I’m celebrating. I finally just slept with my high-school crush. Right? Thank you. Thank you, but I swear, now he, like, expects me to go to his graduation. Like I know where I’m gonna be in three years, right? I’m like, “Whoa!” Slow it down. Fucking kids, right? Fucking small kids. You look, like, upset. Like, I don’t fuck kids. That’s a joke. Like, I would never… I shouldn’t say never. That’s like… you don’t know… I feel like I just painted myself in a corner there. But… that’s not a good way to start.
# ...
